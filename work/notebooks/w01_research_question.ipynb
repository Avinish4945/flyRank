# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Avinish4945/flyRank/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
## My Lane

#I have chosen the **Refresh / Content Opportunity Scoring** lane. My goal is to identify which content pages should be reviewed first for refresh or improvement based on search and engagement signals. I selected this lane because it solves a practical business problem, uses the starter dataset, and can be improved over the next seven weeks. The final output will be a ranked list that helps content teams prioritize their work instead of reviewing every page manually.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
#
#Decision:** Which content pages should be reviewed first for refresh?

#Unit of analysis:** One content page.

#Output:** A ranked list of pages with a refresh priority score.

#Action:** A content reviewer can inspect the highest-ranked pages first and decide whether to refresh, rewrite, expand, or monitor them.

#Cost of a wrong recommendation:** If a page is incorrectly prioritized, reviewers waste time. If an important declining page is missed, valuable traffic and business opportunities may be lost.

#Why data/ML can help:** Many measurable signals such as impressions, clicks, CTR, content age, and engagement influence page performance. Machine learning can combine these signals to support better prioritization than simple manual rules.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
#The starter dataset contains **30,000 content pages** from **32 unique clients** with **44 features**. On average, a page receives **5,200.37 impressions** and **37.07 sessions** over the last 90 days. These numbers show that the dataset has enough scale and variation to build a meaningful refresh prioritization system over the next seven weeks.

# %%
# !git clone https://github.com/Avinish4945/flyRank.git
# Out:
# Cloning into 'flyRank'...
# remote: Enumerating objects: 119, done.
# remote: Counting objects: 100% (119/119), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 119 (delta 35), reused 94 (delta 27), pack-reused 0 (from 0)
# Receiving objects: 100% (119/119), 1.84 MiB | 13.02 MiB/s, done.
# Resolving deltas: 100% (35/35), done.

# %%
import pandas as pd

df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")

print("Rows:", len(df))
print("Columns:", len(df.columns))
print("Unique Clients:", df["client_id"].nunique())
print("Unique Pages:", df["content_id"].nunique())
print("Average 90-day Impressions:", round(df["impressions_90d"].mean(), 2))
print("Average 90-day Sessions:", round(df["sessions_90d"].mean(), 2))
# Out:
# Rows: 30000
# Columns: 44
# Unique Clients: 32
# Unique Pages: 30000
# Average 90-day Impressions: 5200.37
# Average 90-day Sessions: 37.07

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

#This project provides **decision support** rather than proof. It identifies pages that appear to have higher refresh opportunities based on observed search and engagement signals. The recommendations are directional and should help content teams prioritize which pages to review first. This project cannot prove that refreshing a page will increase traffic, nor can it predict Google's ranking algorithm. Any recommended action should always be reviewed by a human before implementation.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
